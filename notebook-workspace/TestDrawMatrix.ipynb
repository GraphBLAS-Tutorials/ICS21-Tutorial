# %%
import pygraphblas as grb
from pathlib import Path

A = grb.Matrix.random(grb.UINT8, 10, 10, 10)
grb.gviz.draw_matrix(A, scale=50, font_path=Path('.'), cmap="Blues")
# Out:
# <PIL.Image.Image image mode=RGB size=551x551 at 0x7FDC6F86D880>
